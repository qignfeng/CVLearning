# %%
import cv2
import random
import numpy as np 
from matplotlib import pyplot as plt

# %%
## img = cv2.imread('E://gitCode/jupyterCode/1.jpg', 1)
img = cv2.imread('1.jpg', 1)
cv2.imshow('plane', img)
key = cv2.waitKey()
if key == 27:
    cv2.destroyAllWindows()

# %%
plt.imshow(img)

# %%
B,G,R = cv2.split(img)
img_rgb = cv2.merge((R,G,B))
plt.imshow(img_rgb)

# %%
plt.imshow(R)

# %%
plt.imshow(G)

# %%
plt.imshow(B)

# %%
print(R)
# Out:
# [[129 129 129 ... 134 134 134]
#  [129 129 129 ... 134 134 134]
#  [129 129 129 ... 134 134 134]
#  ...
#  [134 134 134 ... 137 137 137]
#  [134 134 134 ... 137 137 137]
#  [134 134 134 ... 137 137 137]]

# %%
print(img)
# Out:
# [[[203 144 129]
#   [203 144 129]
#   [203 144 129]
#   ...
#   [204 149 134]
#   [204 149 134]
#   [204 149 134]]
#
#  [[203 144 129]
#   [203 144 129]
#   [203 144 129]
#   ...
#   [204 149 134]
#   [204 149 134]
#   [204 149 134]]
#
#  [[203 144 129]
#   [203 144 129]
#   [203 144 129]
#   ...
#   [204 149 134]
#   [204 149 134]
#   [204 149 134]]
#
#  ...
#
#  [[204 149 134]
#   [204 149 134]
#   [204 149 134]
#   ...
#   [207 152 137]
#   [207 152 137]
#   [207 152 137]]
#
#  [[204 149 134]
#   [204 149 134]
#   [204 149 134]
#   ...
#   [207 152 137]
#   [207 152 137]
#   [207 152 137]]
#
#  [[204 149 134]
#   [204 149 134]
#   [204 149 134]
#   ...
#   [207 152 137]
#   [207 152 137]
#   [207 152 137]]]

# %%
print(img.dtype)
# Out:
# uint8

# %%
print(img.shape)
# Out:
# (421, 634, 3)

# %%
## plt的使用，缩放
plt.figure(figsize=2,1))
plt.imshow(img,cmap='gray')
plt.show()
# Out:
#   File "<ipython-input-43-1cb3cee20b11>", line 2
#     plt.figure(figsize=2,1))
#                            ^
# SyntaxError: invalid syntax

# %%
plt.subplot(121)
plt.imshow(img)
plt.subplot(122)
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
##定义函数
def my_show(img2,size=(3,3)):
    plt.figure(figsize=size)
    plt.imshow(cv2.cvtColor(img2,cv2.COLOR_BGR2RGB))
    plt.show()

# %%
my_show(img)

# %%
my_show(img[150:300][200:300])
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-10-f2f10e23b2bb> in <module>
# ----> 1 my_show(img[150:300][200:300])
#
# <ipython-input-9-1c0ffb1911bc> in my_show(img2, size)
#       2 def my_show(img2,size=(3,3)):
#       3     plt.figure(figsize=size)
# ----> 4     plt.imshow(cv2.cvtColor(img2,cv2.COLOR_BGR2RGB))
#       5     plt.show()
#
# error: OpenCV(4.1.2) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
B,G,R = cv2.split(img)

# %%
B
# Out:
# array([[203, 203, 203, ..., 204, 204, 204],
#        [203, 203, 203, ..., 204, 204, 204],
#        [203, 203, 203, ..., 204, 204, 204],
#        ...,
#        [204, 204, 204, ..., 207, 207, 207],
#        [204, 204, 204, ..., 207, 207, 207],
#        [204, 204, 204, ..., 207, 207, 207]], dtype=uint8)

# %%
def img_coolor(img1,b_increase,b_decrease):
    B,G,R = cv2.split(img1)
